# %% [markdown]
# # Day 1: Python Fundamentals — Exercises
#
# **Duration**: ~2 Hours
# **Goal**: Reinforce the concepts from the Day 1 Teaching Notebook through hands-on practice.
#
# > 💡 **How to use this notebook:**
# > - Read each exercise description carefully.
# > - Write your solution in the provided code cell.
# > - Run the cell to check your output.
# > - Hints are available if you get stuck — look for the collapsible `# HINT` comments.
#
# ---

# %% [markdown]
# ## Section 1: Variables, Data Types & Operators
#
# ---
#
# ### Exercise 1.1 — Personal Profile
#
# Create variables to store the following personal details, then print a formatted summary:
#
# - Your name (string)
# - Your age (integer)
# - Your height in metres (float)
# - Whether you are currently employed (boolean)
#
# **Expected output (example):**
# ```
# Name: Alice | Age: 28 | Height: 1.72m | Employed: True
# ```

# %%
# Exercise 1.1 — Your solution here

# HINT: Use f-strings for clean formatting: f"Name: {name}"

# %% [markdown]
# ---
#
# ### Exercise 1.2 — Type Conversion
#
# You receive the following data as strings from a web form. Convert each to its correct data type and perform the calculations below.
#
# ```python
# price_str = "249.99"
# quantity_str = "4"
# discount_str = "15"
# ```
#
# Calculate and print:
# 1. Total cost before discount (`price × quantity`)
# 2. Discount amount (`total × discount / 100`)
# 3. Final price after discount
#
# **Expected output:**
# ```
# Total before discount: 999.96
# Discount (15%): 149.99
# Final price: 849.97
# ```

# %%
price_str = "249.99"
quantity_str = "4"
discount_str = "15"

# Exercise 1.2 — Your solution here

# HINT: Use float() and int() to convert strings
# HINT: Use round(value, 2) to round to 2 decimal places

# %% [markdown]
# ---
#
# ### Exercise 1.3 — Operators
#
# Given `a = 17` and `b = 5`, compute and print:
# 1. Integer (floor) division result
# 2. Remainder after division
# 3. `a` to the power of `b`
# 4. Is `a` greater than `b` **AND** is `a` even? (True/False)
# 5. Is `a` divisible by either 3 or 5? (True/False)

# %%
a = 17
b = 5

# Exercise 1.3 — Your solution here

# HINT: Use // for floor division, % for modulus, ** for power
# HINT: a % 2 == 0 checks if a number is even

# %% [markdown]
# ---
# ## Section 2: Data Structures
#
# ---
#
# ### Exercise 2.1 — Lists
#
# You are given a list of temperatures (°C) recorded over a week:
#
# ```python
# temperatures = [22, 19, 25, 30, 28, 17, 21]
# ```
#
# Perform the following operations:
# 1. Print the first and last temperature.
# 2. Print the temperatures from Wednesday to Friday (index 2–4).
# 3. Add a new temperature `23` for the next day.
# 4. Sort the list in descending order and print it.
# 5. Print the average temperature (use `sum()` and `len()`).

# %%
temperatures = [22, 19, 25, 30, 28, 17, 21]

# Exercise 2.1 — Your solution here

# HINT: List slicing: my_list[start:end]
# HINT: .append() adds to end, .sort(reverse=True) sorts descending

# %% [markdown]
# ---
#
# ### Exercise 2.2 — Dictionaries
#
# Create a dictionary called `product` with the following keys and values:
# - `name`: `"Wireless Mouse"`
# - `price`: `599.00`
# - `stock`: `150`
# - `category`: `"Electronics"`
#
# Then:
# 1. Print the product name and price.
# 2. Update the stock to `120`.
# 3. Add a new key `"rating"` with value `4.5`.
# 4. Print all keys and values using a loop.
# 5. Safely access a key `"discount"` that doesn't exist — print `0` as a default using `.get()`.

# %%
# Exercise 2.2 — Your solution here

# HINT: dict.get('key', default_value) returns default if key is missing
# HINT: for key, value in my_dict.items(): iterates over key-value pairs

# %% [markdown]
# ---
#
# ### Exercise 2.3 — Sets
#
# You have two lists of customer IDs who bought products A and B:
#
# ```python
# buyers_a = [101, 102, 103, 104, 105, 102, 103]
# buyers_b = [103, 104, 106, 107, 108, 104]
# ```
#
# Using sets, find:
# 1. Unique buyers of product A.
# 2. Customers who bought **both** products (intersection).
# 3. Customers who bought **only** product A (difference).
# 4. Total unique customers across both products (union).

# %%
buyers_a = [101, 102, 103, 104, 105, 102, 103]
buyers_b = [103, 104, 106, 107, 108, 104]

# Exercise 2.3 — Your solution here

# HINT: Convert lists to sets: set(my_list)
# HINT: set_a & set_b → intersection, set_a - set_b → difference, set_a | set_b → union

# %% [markdown]
# ---
# ## Section 3: Comprehensions
#
# ---
#
# ### Exercise 3.1 — List Comprehensions
#
# Using list comprehensions (single lines of code), create:
# 1. A list of squares for numbers 1–15.
# 2. A list of even numbers between 1 and 50.
# 3. A list of words from the sentence below that have more than 4 characters.
#
# ```python
# sentence = "Python is a powerful and versatile programming language"
# ```

# %%
sentence = "Python is a powerful and versatile programming language"

# Exercise 3.1 — Your solution here

# HINT: [expression for item in iterable if condition]
# HINT: sentence.split() splits a string into words

# %% [markdown]
# ---
#
# ### Exercise 3.2 — Dictionary Comprehensions
#
# Given the employee list below, use dictionary comprehensions to create:
# 1. A dictionary mapping `name → salary`.
# 2. A dictionary mapping `name → salary` but **only for employees earning more than 80,000**.
# 3. A dictionary mapping `name → salary_after_10%_raise` for all employees.
#
# ```python
# employees = [
#     {"name": "Alice", "salary": 85000},
#     {"name": "Bob", "salary": 72000},
#     {"name": "Charlie", "salary": 95000},
#     {"name": "Diana", "salary": 68000},
# ]
# ```

# %%
employees = [
    {"name": "Alice", "salary": 85000},
    {"name": "Bob", "salary": 72000},
    {"name": "Charlie", "salary": 95000},
    {"name": "Diana", "salary": 68000},
]

# Exercise 3.2 — Your solution here

# HINT: {emp['name']: emp['salary'] for emp in employees}

# %% [markdown]
# ---
# ## Section 4: Control Flow
#
# ---
#
# ### Exercise 4.1 — Grade Classifier
#
# Write a function `classify_grade(score)` that returns a grade letter based on the rules:
#
# | Score | Grade |
# |-------|-------|
# | 90–100 | A |
# | 80–89 | B |
# | 70–79 | C |
# | 60–69 | D |
# | Below 60 | F |
#
# Test it with scores: `[95, 82, 73, 61, 45, 100, 59]`.

# %%
# Exercise 4.1 — Your solution here

def classify_grade(score):
    # HINT: Use if/elif/else
    pass

# Test your function
test_scores = [95, 82, 73, 61, 45, 100, 59]
for score in test_scores:
    print(f"Score: {score} → Grade: {classify_grade(score)}")

# %% [markdown]
# ---
#
# ### Exercise 4.2 — Loop Practice
#
# 1. Use a `for` loop with `enumerate` to print each item in the list below with its 1-based position:
#
# ```python
# cities = ["Mumbai", "Delhi", "Bangalore", "Chennai", "Hyderabad"]
# ```
#
# Expected: `1. Mumbai`, `2. Delhi`, ...
#
# 2. Use a `while` loop to find the **first number greater than 1 that is divisible by both 7 and 11** (start from 1, increment by 1).

# %%
cities = ["Mumbai", "Delhi", "Bangalore", "Chennai", "Hyderabad"]

# Part 1 — enumerate loop
# HINT: for index, city in enumerate(cities, start=1):


# Part 2 — while loop
# HINT: Use n % 7 == 0 and n % 11 == 0 as your condition

# %% [markdown]
# ---
# ## Section 5: Functions
#
# ---
#
# ### Exercise 5.1 — Statistics Calculator
#
# Write a function `calculate_stats(numbers)` that accepts a list of numbers and returns a **dictionary** containing:
# - `min` — minimum value
# - `max` — maximum value
# - `mean` — average (rounded to 2 decimal places)
# - `range` — difference between max and min
# - `count` — number of items
#
# Test with: `[45, 82, 17, 63, 90, 38, 55, 71]`

# %%
# Exercise 5.1 — Your solution here

def calculate_stats(numbers):
    # HINT: Use min(), max(), sum(), len() built-in functions
    # HINT: Return a dictionary {"min": ..., "max": ..., ...}
    pass

# Test
data = [45, 82, 17, 63, 90, 38, 55, 71]
stats = calculate_stats(data)
for key, val in stats.items():
    print(f"{key}: {val}")

# %% [markdown]
# ---
#
# ### Exercise 5.2 — Lambda & Higher-Order Functions
#
# Using the employee list from Exercise 3.2, apply lambda functions with `sorted`, `map`, and `filter` to:
#
# 1. Sort employees by salary in **descending** order.
# 2. Use `map` to create a list of strings: `"Alice earns 85000"` for each employee.
# 3. Use `filter` to get only employees with salary between 70,000 and 90,000.

# %%
employees = [
    {"name": "Alice", "salary": 85000},
    {"name": "Bob", "salary": 72000},
    {"name": "Charlie", "salary": 95000},
    {"name": "Diana", "salary": 68000},
]

# Part 1 — Sort by salary descending
# HINT: sorted(list, key=lambda x: x['salary'], reverse=True)


# Part 2 — map to strings
# HINT: list(map(lambda emp: f"...", employees))


# Part 3 — filter by salary range
# HINT: list(filter(lambda emp: 70000 <= emp['salary'] <= 90000, employees))

# %% [markdown]
# ---
# ## Section 6: Exception Handling
#
# ---
#
# ### Exercise 6.1 — Safe Division
#
# Write a function `safe_divide(a, b)` that:
# - Returns the result of `a / b`.
# - Catches `ZeroDivisionError` and returns `None` with a message.
# - Catches `TypeError` if non-numeric values are passed and returns `None` with a message.
#
# Test with: `(10, 2)`, `(5, 0)`, `("hello", 3)`, `(100, 4)`.

# %%
# Exercise 6.1 — Your solution here

def safe_divide(a, b):
    # HINT: try / except ZeroDivisionError / except TypeError
    pass

# Test cases
test_cases = [(10, 2), (5, 0), ("hello", 3), (100, 4)]
for a, b in test_cases:
    print(f"safe_divide({a}, {b}) = {safe_divide(a, b)}")

# %% [markdown]
# ---
#
# ### Exercise 6.2 — Custom Exception
#
# Create a custom exception `NegativeSalaryError`. Then write a function `set_salary(salary)` that raises this exception if the salary is negative, otherwise returns the salary.
#
# Test with: `-5000`, `75000`, `-1`, `0`.

# %%
# Exercise 6.2 — Your solution here

# HINT: class NegativeSalaryError(Exception): ...

class NegativeSalaryError(Exception):
    pass  # Replace with your implementation

def set_salary(salary):
    pass  # Replace with your implementation

# Test cases
for s in [-5000, 75000, -1, 0]:
    try:
        result = set_salary(s)
        print(f"Salary set to: {result}")
    except NegativeSalaryError as e:
        print(f"Error for {s}: {e}")

# %% [markdown]
# ---
# ## Section 7: File I/O
#
# ---
#
# ### Exercise 7.1 — CSV Read & Write
#
# 1. Write the employee data below to a file called `staff.csv`.
# 2. Read the file back and print each row.
# 3. Count how many employees are in the `Engineering` department.
#
# ```python
# staff = [
#     ["Name", "Department", "Salary"],
#     ["Alice", "Engineering", 85000],
#     ["Bob", "Marketing", 72000],
#     ["Charlie", "Engineering", 91000],
#     ["Diana", "HR", 67000],
#     ["Eve", "Engineering", 88000],
# ]
# ```

# %%
import csv

staff = [
    ["Name", "Department", "Salary"],
    ["Alice", "Engineering", 85000],
    ["Bob", "Marketing", 72000],
    ["Charlie", "Engineering", 91000],
    ["Diana", "HR", 67000],
    ["Eve", "Engineering", 88000],
]

# Exercise 7.1 — Your solution here

# HINT: with open('staff.csv', 'w', newline='') as f:
#           writer = csv.writer(f)
#           writer.writerows(staff)

# HINT: with open('staff.csv', 'r') as f:
#           reader = csv.reader(f)

# %% [markdown]
# ---
#
# ### Exercise 7.2 — JSON File Operations
#
# 1. Save the dictionary below as `config.json` with indentation of 4.
# 2. Read it back and print the database host and port.
# 3. Add a new key `"debug": True` and save the updated config.
#
# ```python
# config = {
#     "app_name": "DataPipeline",
#     "version": "1.0",
#     "database": {
#         "host": "localhost",
#         "port": 5432,
#         "name": "production_db"
#     },
#     "max_retries": 3
# }
# ```

# %%
import json

config = {
    "app_name": "DataPipeline",
    "version": "1.0",
    "database": {
        "host": "localhost",
        "port": 5432,
        "name": "production_db"
    },
    "max_retries": 3
}

# Exercise 7.2 — Your solution here

# HINT: json.dump(data, file, indent=4) to write
# HINT: json.load(file) to read

# %% [markdown]
# ---
# ## Section 8: Object-Oriented Programming
#
# ---
#
# ### Exercise 8.1 — BankAccount Class
#
# Create a `BankAccount` class with:
#
# **Attributes:**
# - `owner` (str)
# - `balance` (float, default `0.0`)
# - `transactions` (list, default empty)
#
# **Methods:**
# - `deposit(amount)` — adds to balance, records transaction, raises `ValueError` if amount ≤ 0
# - `withdraw(amount)` — subtracts from balance, records transaction, raises `ValueError` if insufficient funds or amount ≤ 0
# - `get_balance()` — returns current balance
# - `print_statement()` — prints all transactions with running balance
#
# Test your class with at least 3 deposits and 2 withdrawals.

# %%
# Exercise 8.1 — Your solution here

class BankAccount:
    def __init__(self, owner, balance=0.0):
        # HINT: Initialize attributes here
        pass
    
    def deposit(self, amount):
        # HINT: Validate amount > 0, update balance, record transaction
        pass
    
    def withdraw(self, amount):
        # HINT: Validate amount > 0 and balance >= amount
        pass
    
    def get_balance(self):
        pass
    
    def print_statement(self):
        # HINT: Loop through self.transactions and print each
        pass


# Test your class
account = BankAccount("Alice")
account.deposit(10000)
account.deposit(5000)
account.withdraw(3000)
account.deposit(2500)
account.withdraw(1000)
account.print_statement()
print(f"Final balance: {account.get_balance()}")

# %% [markdown]
# ---
#
# ### Exercise 8.2 — Inheritance
#
# Create a `SavingsAccount` class that **inherits** from `BankAccount` and adds:
#
# - An `interest_rate` attribute (e.g., `0.05` for 5%)
# - A method `apply_interest()` that adds `balance × interest_rate` to the balance and records it as a transaction.
#
# Test by creating a savings account, depositing money, applying interest, and printing the statement.

# %%
# Exercise 8.2 — Your solution here

class SavingsAccount(BankAccount):
    def __init__(self, owner, interest_rate=0.05, balance=0.0):
        # HINT: Call super().__init__(owner, balance)
        pass
    
    def apply_interest(self):
        # HINT: interest = self.balance * self.interest_rate
        # Then deposit the interest amount
        pass

# Test
savings = SavingsAccount("Bob", interest_rate=0.08)
savings.deposit(50000)
savings.apply_interest()
savings.withdraw(5000)
savings.apply_interest()
savings.print_statement()

# %% [markdown]
# ---
# ## 🏁 Capstone Exercise — Employee Management System
#
# This is your final challenge combining everything from Day 1.
#
# **Task:** Build a simple employee management system that:
#
# 1. Creates a class `EmployeeManager` with an internal list of employees.
# 2. Supports adding employees (`name`, `department`, `salary`) via an `add_employee` method.
# 3. Has a method `get_by_department(dept)` that returns all employees in that department.
# 4. Has a method `average_salary(dept=None)` — average across all employees or within a department.
# 5. Has a method `save_to_csv(filename)` that saves all employees to a CSV file.
# 6. Has a class method `load_from_csv(filename)` that reads the CSV and returns a new `EmployeeManager` instance.
#
# **Test with at least 6 employees across 3 departments.**

# %%
import csv

# Capstone — Your solution here

class EmployeeManager:
    def __init__(self):
        self.employees = []
    
    def add_employee(self, name, department, salary):
        pass
    
    def get_by_department(self, dept):
        pass
    
    def average_salary(self, dept=None):
        pass
    
    def save_to_csv(self, filename):
        pass
    
    @classmethod
    def load_from_csv(cls, filename):
        pass


# Test your implementation
manager = EmployeeManager()
manager.add_employee("Alice",   "Engineering", 85000)
manager.add_employee("Bob",     "Marketing",   72000)
manager.add_employee("Charlie", "Engineering", 91000)
manager.add_employee("Diana",   "HR",           67000)
manager.add_employee("Eve",     "Engineering", 88000)
manager.add_employee("Frank",   "Marketing",   78000)

print("Engineering employees:", manager.get_by_department("Engineering"))
print(f"Overall average salary: {manager.average_salary():.2f}")
print(f"Engineering average salary: {manager.average_salary('Engineering'):.2f}")

manager.save_to_csv("employees.csv")
print("Saved to employees.csv")

loaded = EmployeeManager.load_from_csv("employees.csv")
print(f"Loaded {len(loaded.employees)} employees from CSV")

# %% [markdown]
# ---
#
# ## ✅ Well done!
#
# You have practised:
# - Variables, types, and operators
# - Lists, dictionaries, tuples, and sets
# - List and dictionary comprehensions
# - Control flow — if/elif/else, for loops, while loops
# - Functions — default args, *args, **kwargs, lambdas
# - Exception handling and custom exceptions
# - CSV and JSON file I/O
# - OOP — classes, methods, inheritance
#
# Move on to **Day 2 Exercises** when you're ready! 🚀
